# %%
import numpy as np
import matplotlib.pyplot as plt

df = np.load("./analysis_data/pdop_corr_data.npy")
maxx = 200
ind = ~np.isnan(df[:,1])
plt.plot(df[ind,1][:maxx])
ind = ~np.isnan(df[:,2])
plt.plot(df[ind,2][:maxx])
